# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Passenger_Satisfaction.csv')
df = df.drop(['Unnamed: 0'], axis = 1)
df.head()
# Out:
#        id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    Ease of Online booking  ...  Inflight entertainment  On-board service  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 103904 non-null  int64
#  1   Gender                             103904 non-null  object
#  2   Customer Type                      103904 non-null  object
#  3   Age                                103904 non-null  int64
#  4   Type of Travel                     103904 non-null  object
#  5   Class                              103904 non-null  object
#  6   Flight Distance                    103904 non-null  int64
#  7   Inflight wifi service              103904 non-null  int64
#  8   Departure/Arrival time convenient  103904 non-null  int64
#  9   Ease of Online booking             103904 non-null  int64
#  10  Gate location                      103904 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# ...

# %%
# df.dropna(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 103904 non-null  int64
#  1   Gender                             103904 non-null  object
#  2   Customer Type                      103904 non-null  object
#  3   Age                                103904 non-null  int64
#  4   Type of Travel                     103904 non-null  object
#  5   Class                              103904 non-null  object
#  6   Flight Distance                    103904 non-null  int64
#  7   Inflight wifi service              103904 non-null  int64
#  8   Departure/Arrival time convenient  103904 non-null  int64
#  9   Ease of Online booking             103904 non-null  int64
#  10  Gate location                      103904 non-null  int64
# ...

# %%
df.isna().sum()
# Out:
# id                                     0
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# ...

# %%
sns.scatterplot(df, x = 'Departure Delay in Minutes', y = 'Arrival Delay in Minutes')
# Out:
# <Axes: xlabel='Departure Delay in Minutes', ylabel='Arrival Delay in Minutes'>

# %%
# df = df.drop('Arrival Delay in Minutes', axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   id                                 103904 non-null  int64
#  1   Gender                             103904 non-null  object
#  2   Customer Type                      103904 non-null  object
#  3   Age                                103904 non-null  int64
#  4   Type of Travel                     103904 non-null  object
#  5   Class                              103904 non-null  object
#  6   Flight Distance                    103904 non-null  int64
#  7   Inflight wifi service              103904 non-null  int64
#  8   Departure/Arrival time convenient  103904 non-null  int64
#  9   Ease of Online booking             103904 non-null  int64
#  10  Gate location                      103904 non-null  int64
# ...

# %%
df = df.drop('id', axis = 1)

# %%
Passenger_info = ['Gender', 'Age']

travel_info = ['Flight Distance', 'Departure Delay in Minutes', 'Arrival Delay in Minutes','Type of Travel', 'Class' ]


inflight_service = ['Inflight wifi service','Food and drink','Seat comfort','Inflight entertainment','Leg room service', 'Inflight service',
       'Cleanliness']

boarding_service = ['Departure/Arrival time convenient', 'Ease of Online booking',
       'Gate location', 'Online boarding', 'On-board service', 'Baggage handling', 'Checkin service',]

# %%
#Age Group
group_1 = np.arange(7, 13, 1)
group_2 = np.arange(13, 20, 1)
group_3 = np.arange(20, 36, 1)
group_4 = np.arange(36, 51, 1)
group_5= np.arange(51, 66, 1)
group_6 = np.arange(66, 86, 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 103594 entries, 0 to 103903
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             103594 non-null  object
#  1   Customer Type                      103594 non-null  object
#  2   Age                                103594 non-null  int64
#  3   Type of Travel                     103594 non-null  object
#  4   Class                              103594 non-null  object
#  5   Flight Distance                    103594 non-null  int64
#  6   Inflight wifi service              103594 non-null  int64
#  7   Departure/Arrival time convenient  103594 non-null  int64
#  8   Ease of Online booking             103594 non-null  int64
#  9   Gate location                      103594 non-null  int64
#  10  Food and drink                     103594 non-null  int64
# ...

# %%
for i in range(df.shape[0]):
    if df['Age'].iloc[i] in group_1:
        df.loc[i, 'age_group']= 1
    elif df['Age'].iloc[i] in group_2:
        df.loc[i, 'age_group']= 2
    elif df['Age'].iloc[i] in group_3:
        df.loc[i, 'age_group'] = 3
    elif df['Age'].iloc[i] in group_4:
        df.loc[i, 'age_group'] = 4
    elif df['Age'].iloc[i] in group_5:
        df.loc[i, 'age_group'] = 5
    else:
        df.loc[i, 'age_group'] = 6

# %%
df.isnull().sum(0)
# Out:
# Gender                                 0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Inflight wifi service                  0
# Departure/Arrival time convenient      0
# Ease of Online booking                 0
# Gate location                          0
# Food and drink                         0
# Online boarding                        0
# Seat comfort                           0
# Inflight entertainment                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Inflight service                       0
# Cleanliness                            0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             310
# satisfaction                           0
# ...

# %%
df1 = df.copy()

# %%
# for i in range(df1.shape[0]):
#     if df1['Age'].iloc[i] in group_1:
#         df1.loc[i, 'age_group']= 1
#     elif df1['Age'].iloc[i] in group_2:
#         df1.loc[i, 'age_group']= 2
#     elif df1['Age'].iloc[i] in group_3:
#         df1.loc[i, 'age_group'] = 3
#     elif df1['Age'].iloc[i] in group_4:
#         df1.loc[i, 'age_group'] = 4
#     elif df1['Age'].iloc[i] in group_5:
#         df1.loc[i, 'age_group'] = 5
#     else:
#         df1.loc[i, 'age_group'] = 6

# %%
df
# Out:
#         Gender      Customer Type  Age   Type of Travel     Class  \
# 0         Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1         Male  disloyal Customer   25  Business travel  Business
# 2       Female     Loyal Customer   26  Business travel  Business
# 3       Female     Loyal Customer   25  Business travel  Business
# 4         Male     Loyal Customer   61  Business travel  Business
# ...        ...                ...  ...              ...       ...
# 103899  Female  disloyal Customer   23  Business travel       Eco
# 103900    Male     Loyal Customer   49  Business travel  Business
# 103901    Male  disloyal Customer   30  Business travel  Business
# 103902  Female  disloyal Customer   22  Business travel       Eco
# 103903    Male     Loyal Customer   27  Business travel  Business
#
#         Flight Distance  Inflight wifi service  \
# 0                   460                      3
# 1                   235                      3
# ...

# %%
df.to_csv('satisfaction_data.csv')

# %%
df.dropna(inplace = True)

# %%
df.age_group.value_counts()
# Out:
# age_group
# 4.0    35698
# 3.0    31648
# 5.0    22739
# 2.0     5923
# 6.0     4006
# 1.0     3890
# Name: count, dtype: int64

# %% [markdown]
# ### Analyzing Passengers

# %% [markdown]
# #### Distribution of Gender

# %%
df.Gender.value_counts(normalize = True)
# Out:
# Gender
# Female    0.507459
# Male      0.492541
# Name: proportion, dtype: float64

# %% [markdown]
# #### Distribution of Age among Gender

# %%
df.groupby('Gender')['age_group'].value_counts(normalize=True).plot(kind = 'bar', figsize = (13, 4))
# Out:
# <Axes: xlabel='Gender,age_group'>

# %%
sns.set_style('whitegrid')

# %% [markdown]
# #### Customer Type, Age Group and Gender

# %%
df.groupby(['Gender', 'age_group'])['Customer Type'].value_counts(normalize=True).plot(kind = 'bar', figsize = (13, 4))
# Out:
# <Axes: xlabel='Gender,age_group,Customer Type'>

# %% [markdown]
# ### Analyzing Ratings by Passengers

# %% [markdown]
# #### Rating of 'Boarding Services' by Male passengers

# %%
plt.figure(figsize=(15, 4))
sns.lineplot(df[df['Gender']=='Male'].groupby('age_group')[boarding_service].mean())
# Out:
# <Axes: xlabel='age_group'>

# %% [markdown]
# #### Rating of Boarding Services by Femae Passengers

# %%
plt.figure(figsize=(15, 4))
sns.lineplot(df[df['Gender']=='Female'].groupby('age_group')[boarding_service].mean())
# Out:
# <Axes: xlabel='age_group'>

# %%
df2 = df[df['Gender']=='Female'].groupby('age_group')[boarding_service].mean()
df2.reset_index(inplace=True)
df2['age_group']=df2['age_group'].astype('int')
# df2.set_index('age_group', inplace = True)
df2
# Out:
#    age_group  Departure/Arrival time convenient  Ease of Online booking  \
# 0          1                           3.390863                2.550761
# 1          2                           3.243109                2.605779
# 2          3                           2.869403                2.704196
# 3          4                           3.037074                2.818025
# 4          5                           3.144347                2.784487
# 5          6                           3.377137                2.660967
#
#    Gate location  Online boarding  On-board service  Baggage handling  \
# 0       2.920812         2.566497          3.223858          3.693401
# 1       3.010960         2.653271          3.206244          3.687147
# 2       2.977580         2.923124          3.247902          3.652680
# 3       2.990537         3.544255          3.488087          3.611890
# 4       2.961262         3.744785          3.490096          3.510079
# ...

# %% [markdown]
# 'Gate Location' is ALMOST UNIFORMALLY RATED' between all age groups.
# Rating pattern of 'Departure and Arrival Time' in both Male and Female Passengers is same.
# Rating pattern of 'Ease of Online Booking' in both Male and Female Passengers is same.
# Male Passengers in age group 5 have given lover ratings to 'Online Boarding' may be because Females in age group 5 are not doing online boarding by themselves and are assisted by someone.
# Rating pattern of 'Onboard Servises' in both Male and Female Passengers is same.
# Bagage handling in Females of age-group 3 to 6 are inconvennient.
# Checkin Services in Females of age-group 2 are little bit more inconvenient.

# %%
df['satisfaction'].value_counts(normalize = True)
# Out:
# satisfaction
# neutral or dissatisfied    0.566667
# satisfied                  0.433333
# Name: proportion, dtype: float64

# %%
df.groupby('satisfaction')['Gender'].value_counts(normalize = True)
# Out:
# satisfaction             Gender
# neutral or dissatisfied  Female    0.512797
#                          Male      0.487203
# satisfied                Female    0.500478
#                          Male      0.499522
# Name: proportion, dtype: float64

# %%
df.groupby(['satisfaction','Gender'])['Type of Travel'].value_counts(normalize = True)
# Out:
# satisfaction             Gender  Type of Travel
# neutral or dissatisfied  Female  Business travel    0.518431
#                                  Personal Travel    0.481569
#                          Male    Personal Travel    0.503033
#                                  Business travel    0.496967
# satisfied                Female  Business travel    0.926378
#                                  Personal Travel    0.073622
#                          Male    Business travel    0.927971
#                                  Personal Travel    0.072029
# Name: proportion, dtype: float64

# %%
df.groupby(['satisfaction','Gender', 'Type of Travel'])['Class'].value_counts(normalize = True)
# Out:
# satisfaction             Gender  Type of Travel   Class
# neutral or dissatisfied  Female  Business travel  Eco         0.481633
#                                                   Business    0.432186
#                                                   Eco Plus    0.086182
#                                  Personal Travel  Eco         0.820633
#                                                   Eco Plus    0.114374
#                                                   Business    0.064993
#                          Male    Business travel  Eco         0.471240
#                                                   Business    0.457842
#                                                   Eco Plus    0.070918
#                                  Personal Travel  Eco         0.821552
#                                                   Eco Plus    0.112751
#                                                   Business    0.065696
# ...

# %%
df.groupby(['satisfaction','Gender','Customer Type', 'Type of Travel'])['Class'].value_counts(normalize = True)
# Out:
# satisfaction             Gender  Customer Type      Type of Travel   Class
# neutral or dissatisfied  Female  Loyal Customer     Business travel  Business    0.571998
#                                                                      Eco         0.321034
#                                                                      Eco Plus    0.106968
#                                                     Personal Travel  Eco         0.820224
#                                                                      Eco Plus    0.114943
#                                                                      Business    0.064833
#                                  disloyal Customer  Business travel  Eco         0.640254
#                                                                      Business    0.294095
#                                                                      Eco Plus    0.065651
#                                                     Personal Travel  Eco         0.902778
# ...

# %%
df.groupby('Gender')['satisfaction'].value_counts(normalize = True)
# Out:
# Gender  satisfaction
# Female  neutral or dissatisfied    0.572629
#         satisfied                  0.427371
# Male    neutral or dissatisfied    0.560525
#         satisfied                  0.439475
# Name: proportion, dtype: float64

# %%
df.groupby('Class')['satisfaction'].value_counts(normalize = True)
# Out:
# Class     satisfaction
# Business  satisfied                  0.694251
#           neutral or dissatisfied    0.305749
# Eco       neutral or dissatisfied    0.813862
#           satisfied                  0.186138
# Eco Plus  neutral or dissatisfied    0.753936
#           satisfied                  0.246064
# Name: proportion, dtype: float64

# %%
df.groupby('Type of Travel')['satisfaction'].value_counts(normalize = True)
# Out:
# Type of Travel   satisfaction
# Business travel  satisfied                  0.582597
#                  neutral or dissatisfied    0.417403
# Personal Travel  neutral or dissatisfied    0.898322
#                  satisfied                  0.101678
# Name: proportion, dtype: float64

# %%
df.groupby(['Type of Travel', 'Class'])['satisfaction'].value_counts(normalize = True)
# Out:
# Type of Travel   Class     satisfaction
# Business travel  Business  satisfied                  0.720216
#                            neutral or dissatisfied    0.279784
#                  Eco       neutral or dissatisfied    0.703806
#                            satisfied                  0.296194
#                  Eco Plus  neutral or dissatisfied    0.606684
#                            satisfied                  0.393316
# Personal Travel  Business  neutral or dissatisfied    0.877608
#                            satisfied                  0.122392
#                  Eco       neutral or dissatisfied    0.898029
#                            satisfied                  0.101971
#                  Eco Plus  neutral or dissatisfied    0.912875
#                            satisfied                  0.087125
# Name: proportion, dtype: float64

# %% [markdown]
# Passengers travelling for Personnel reasons are less satisfied in business class (only 12.24%) than the travellers travelling for business purposes who are travelling in business class (72%).
#
# _Kutte ko ghee hazam nhi hoti_

# %%
df.groupby(['Class'])['satisfaction'].value_counts(normalize = True)
# Out:
# Class     satisfaction
# Business  satisfied                  0.694251
#           neutral or dissatisfied    0.305749
# Eco       neutral or dissatisfied    0.813862
#           satisfied                  0.186138
# Eco Plus  neutral or dissatisfied    0.753936
#           satisfied                  0.246064
# Name: proportion, dtype: float64

# %%
pd.pivot_table(data = df, values = 'satisfaction', index = 'Class', aggfunc='count')
# Out:
#           satisfaction
# Class
# Business         49665
# Eco              46745
# Eco Plus          7494

# %%
import altair as alt
print(alt.__version__)  # Should display the latest version
# Out:
# 5.5.0

# %%
plt.figure(figsize=(15, 4))
sns.lineplot(df[df['Gender']=='Male'].groupby('age_group')[inflight_service].mean())
# Out:
# <Axes: xlabel='age_group'>

# %%
plt.figure(figsize=(15, 4))
sns.lineplot(df[df['Gender']=='Female'].groupby('age_group')[inflight_service].mean())
# Out:
# <Axes: xlabel='age_group'>

# %%
df[df['Gender']=='Male'].groupby('age_group')[inflight_service].mean()
# Out:
#            Inflight wifi service  Food and drink  Seat comfort  \
# age_group
# 1.0                     2.554167        3.007292      2.964062
# 2.0                     2.683379        3.077610      3.021635
# 3.0                     2.721595        3.224369      3.219866
# 4.0                     2.810815        3.245855      3.587459
# 5.0                     2.739165        3.230912      3.586901
# 6.0                     2.560490        3.045431      3.123022
#
#            Inflight entertainment  Leg room service  Inflight service  \
# age_group
# 1.0                      3.027604          3.221354          3.695312
# 2.0                      3.096497          3.196772          3.694712
# 3.0                      3.249690          3.229459          3.680285
# 4.0                      3.514210          3.526954          3.706158
# 5.0                      3.470209          3.533057          3.695913
# 6.0                      3.075038          3.123022          3.506891
#
# ...

# %%
df[df['Gender']=='Female'].groupby('age_group')[inflight_service].mean()
# Out:
#            Inflight wifi service  Food and drink  Seat comfort  \
# age_group
# 1.0                     2.525888        2.951777      2.932995
# 2.0                     2.605115        3.127864      3.094321
# 3.0                     2.669832        3.188729      3.191485
# 4.0                     2.799432        3.222389      3.640392
# 5.0                     2.744610        3.232603      3.794303
# 6.0                     2.588666        3.116756      3.556424
#
#            Inflight entertainment  Leg room service  Inflight service  \
# age_group
# 1.0                      2.988325          3.210152          3.692893
# 2.0                      3.159748          3.187313          3.697443
# 3.0                      3.224931          3.238224          3.674609
# 4.0                      3.477065          3.447228          3.607326
# 5.0                      3.492200          3.345486          3.508063
# 6.0                      3.070835          2.752809          3.085979
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 24 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   Gender                             103904 non-null  object
#  1   Customer Type                      103904 non-null  object
#  2   Age                                103904 non-null  int64
#  3   Type of Travel                     103904 non-null  object
#  4   Class                              103904 non-null  object
#  5   Flight Distance                    103904 non-null  int64
#  6   Inflight wifi service              103904 non-null  int64
#  7   Departure/Arrival time convenient  103904 non-null  int64
#  8   Ease of Online booking             103904 non-null  int64
#  9   Gate location                      103904 non-null  int64
#  10  Food and drink                     103904 non-null  int64
# ...

# %%
print(df['Flight Distance'].max())
print(df['Flight Distance'].min())
# Out:
# 4983
# 31

# %%
sns.boxplot(data = df, 'Flight Distance')
# Out:
#   Cell In[159], line 1
#     sns.boxplot(data = df, 'Flight Distance')
#                                             ^
# SyntaxError: positional argument follows keyword argument

# %%
df['Flight Distance'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
pd.DataFrame(df.groupby('Gender')['satisfaction'].value_counts(normalize = True)).reset_index()
# Out:
#    Gender             satisfaction  proportion
# 0  Female  neutral or dissatisfied    0.572629
# 1  Female                satisfied    0.427371
# 2    Male  neutral or dissatisfied    0.560525
# 3    Male                satisfied    0.439475

# %%
pd.pivot_table(data=df, index = 'Gender', columns = 'satisfaction', aggfunc = 'count')['Age'].reset_index()
# Out:
# satisfaction  Gender  neutral or dissatisfied  satisfied
# 0             Female                    30193      22534
# 1               Male                    28686      22491

# %%
pd.DataFrame(df.groupby('Class')['satisfaction'].value_counts(normalize=True)).reset_index()
# Out:
#       Class             satisfaction  proportion
# 0  Business                satisfied    0.694251
# 1  Business  neutral or dissatisfied    0.305749
# 2       Eco  neutral or dissatisfied    0.813862
# 3       Eco                satisfied    0.186138
# 4  Eco Plus  neutral or dissatisfied    0.753936
# 5  Eco Plus                satisfied    0.246064

# %%
pd.pivot_table(data=df, index = 'Class', columns = 'satisfaction', aggfunc = 'count')['Age'].reset_index()
# Out:
# satisfaction     Class  neutral or dissatisfied  satisfied
# 0             Business                    15185      34480
# 1                  Eco                    38044       8701
# 2             Eco Plus                     5650       1844

# %%
age_group = {'Group 1': '7 -12',
             'Group 2': '13 - 19',
             'Group 3': '20 - 35',
             'Group 4': '36 - 50',
             'Group 5': '51 - 65',
             'Group 6': '66 - 85'}

pd.DataFrame(pd.DataFrame([age_group]).T)
# Out:
#                0
# Group 1    7 -12
# Group 2  13 - 19
# Group 3  20 - 35
# Group 4  36 - 50
# Group 5  51 - 65
# Group 6  66 - 85

# %%
age_groups = {'age_group' : ['Group 1', 'Group 2','Group 3','Group 4','Group 5','Group 6'],
             'Min Age': [7, 13, 20, 36, 51, 66], 
             'Max Age': [12, 19, 35, 50, 65, 85]
}

pd.DataFrame(age_groups)
# Out:
#   age_group  Min Age  Max Age
# 0   Group 1        7       12
# 1   Group 2       13       19
# 2   Group 3       20       35
# 3   Group 4       36       50
# 4   Group 5       51       65
# 5   Group 6       66       85
